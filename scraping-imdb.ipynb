# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pdp
import cloudscraper
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
# options = webdriver.ChromeOptions()
# options.add_argument('--ignore-certificate-errors')
# options.add_argument('--incognito')
# options.add_argument('--headless')
# driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)

# %%
# webdriver.Chrome()
# path = "C:/Users/HP ENVY/.cache/selenium/chromedriver/win32/112.0.5615.49/chromedriver.exe"
# path = ("C:/Users/HP ENVY/OWASP ZAP/webdriver/windows/32/chromedriver.exe")
# path = "C:/Program Files/Google/Chrome/Application/chrome.exe"
# path = "D:/DOWNLOADS/chromedriver-win64/chromedriver-win64/chromedriver.exe"
path = "D:/DOWNLOADS/chromedriver125/chromedriver-win64/chromedriver.exe"

chrome_options = Options()
chrome_options.add_argument("--headless")
service = Service(path)
# Chrome(options=chrome_options, executable_path='path_to_chromedriver')
browser = webdriver.Chrome(options=chrome_options, service = service)
# browser = webdriver.Chrome(service = service)
# browser.get('https://1xbet.whoscored.com')
browser.get('https://www.google.com')
search_box = browser.find_element('id','APjFqb')
# search_box = browser.find_element('class','gLFyf')

search_box.clear()
search_box.send_keys("bayer leverkusen")

search_btn = browser.find_element('name','btnK')
search_btn.click()

page = browser.page_source
soup = BeautifulSoup(page,'html.parser') 

rows = soup.findAll("div", {"class":"N54PNb BToiNc cvP2Ce"})

for row in rows:
    
# "span",  :""
    link = row.find("a").get('href')
    title = row.find("h3", {"class":"LC20lb MBeuO DKV0Md"}).text
    texts = row.find("span",{"class":""}).text
    print(link)
    print(title)
    print(texts)
    print("")
# print(browser.page_source)
# print(name)
# Out:
# https://www.transfermarkt.co.id/bayer-04-leverkusen/startseite/verein/15
# Bayer 04 Leverkusen - Profil Klub
# Bayer 04 Leverkusen - Profil KlubTransfermarkt.co.idhttps://www.transfermarkt.co.id › startseite › verein
#
# https://www.bayer04.de/en-us
# Bayer 04 Leverkusen Fußball GmbH | bayer04.de
# Bayer 04 Leverkusen Fußball GmbH | bayer04.deBayer 04 Leverkusen Fußball GmbHhttps://www.bayer04.de › en-us
#
# https://id.wikipedia.org/wiki/Bayer_04_Leverkusen
# Bayer 04 Leverkusen - Wikipedia bahasa Indonesia ...
# Bayer 04 Leverkusen - Wikipedia bahasa Indonesia ...Wikipediahttps://id.wikipedia.org › wiki › Bayer_04_Leverkusen
#
# https://www.bola.net/bundesliga/bayer-leverkusen-sudah-bikin-bayern-munchen-marah-awas-skuad-digembosi-a22b0c.html
# Bayer Leverkusen Sudah Bikin Bayern Munchen Marah ...
# Bayer Leverkusen Sudah Bikin Bayern Munchen Marah ...Bola.nethttps://www.bola.net › Bundesliga
#
# https://www.instagram.com/bayer04fussball/
# Bayer 04 Leverkusen (@bayer04fussball)
# Bayer 04 Leverkusen (@bayer04fussball)Instagramhttps://www.instagram.com › bayer04fussball
#
# https://www.detik.com/tag/bayer-leverkusen
# Berita dan Informasi Bayer leverkusen Terkini dan Terbaru ...
# Berita dan Informasi Bayer leverkusen Terkini dan Terbaru ...detikcomhttps://www.detik.com › tag › bayer-leverkusen
#
# https://www.bola.net/bundesliga/bayer-leverkusen-angin-segar-untuk-bundesliga-yang-mulai-membosankan-0a7b7e.html
# Bayer Leverkusen, Angin Segar untuk Bundesliga yang ...
# Bayer Leverkusen, Angin Segar untuk Bundesliga yang ...Bola.nethttps://www.bola.net › Bundesliga
#
# https://en.wikipedia.org/wiki/Bayer_04_Leverkusen
# Bayer 04 Leverkusen
# Bayer 04 LeverkusenWikipediahttps://en.wikipedia.org › B...

# %%
my_url = "http://www.imdb.com/search/title?sort=num_votes,desc&start=1&title_type=feature&year=2020,2024"

# uClient = uReq(my_url)
# page_html = uClient.read()
# uClient.close()

scraper = cloudscraper.create_scraper(delay=10, browser="chrome") 
content = scraper.get(my_url).text 
# content

# %%
containers = BeautifulSoup(content, "html.parser")
# page_soup

filename= "imdb_m.csv"
f= open(filename, "w")

headers= "Name, Year, Durasi(Menit), Rating \n"
f.write(headers)


# for container in containers:
    # name= container.img["alt"]
    # name = container.findAll("span", {"class": "ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN dli-title"})
#     year_mov= container.findAll("span", {"class": "lister-item-year"})
#     year=year_mov[0].text
#     runtime_mov= container.findAll("span", {"class": "runtime"})
#     runtime=runtime_mov[0].text
    
#     print(name + "," + year + "," + runtime +  "\n")
#     f.write(name + "," + year + "," + runtime  + "\n")

movies = containers.find_all("div", {"class":"sc-b189961a-0 hBZnfJ"})

# sc-b189961a-0 hBZnfJ
# sc-b189961a-8 kLaxqf dli-title-metadata-item
for movie in movies:
    name = re.sub(r"\d+. ","", movie.find("h3", {"class": "ipc-title__text"}).text)
    detil_line = movie.findAll("span", {"class": "sc-b189961a-8 kLaxqf dli-title-metadata-item"})
    if len(detil_line) > 2:        
        year_movie = detil_line[0].text
        durasi = detil_line[1].text
        durasi = durasi.split(" ")
        if len(durasi) > 1:
            menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
        else:
            menit = int(durasi[0].replace("h","")) * 60 
        # durasi_menit = 
        rating = detil_line[2].text
    elif len(detil_line) > 1:
        year_movie = detil_line[0].text
        durasi = detil_line[1].text
        durasi = durasi.split(" ")
        if len(durasi) > 1:
            menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
        else:
            menit = int(durasi[0].replace("h","")) * 60 
    else:
        year_movie = detil_line[0].text
        
    print(name + "," + year_movie + "," + str(menit) + "," + rating)  
    f.write(name + "," + year_movie + "," + str(menit) + "," + rating + "\n")
    
    
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pdp
import cloudscraper
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Optionsf.close()
# Out:
# Spider-Man: No Way Home,2021,148,PG-13
# Dune,2021,155,PG-13
# The Batman,2022,176,PG-13
# Oppenheimer,2023,180,R
# Top Gun: Maverick,2022,130,PG-13
# Don't Look Up,2021,138,R
# Tenet,2020,150,PG-13
# The Kashmir Files,2022,170,Not Rated
# Barbie,2023,114,PG-13
# Everything Everywhere All at Once,2022,139,R
# Avatar: The Way of Water,2022,192,PG-13
# Doctor Strange in the Multiverse of Madness,2022,126,PG-13
# No Time to Die,2021,163,PG-13
# Glass Onion,2022,139,PG-13
# Zack Snyder's Justice League,2021,242,R
# Shang-Chi and the Legend of the Ten Rings,2021,132,PG-13
# Bullet Train,2022,127,R
# Free Guy,2021,115,PG-13
# Black Widow,2021,134,PG-13
# The Suicide Squad,2021,132,R
# Dune: Part Two,2024,166,PG-13
# Thor: Love and Thunder,2022,118,PG-13
# The Menu,2022,107,R
# Eternals,2021,156,PG-13
# Guardians of the Galaxy Vol. 3,2023,150,PG-13
# Soul,2020,100,PG
# Spider-Man: Across the Spider-Verse,2023,140,PG
# John Wick: Chapter 4,2023,169,R
# Nobody,2021,92,R
# Red Notice,2021,118,PG-13
# Black Panther: Wakanda Forever,2022,161,PG-13
# Wonder Woman 1984,2020,151,PG-13
# The Matrix Resurrections,2021,148,R
# Black Adam,2022,125,PG-13
# A Quiet Place Part II,2020,97,PG-13
# Nope,2022,130,R
# Cruella,2021,134,PG-13
# Birds of Prey,2020,109,R
# Extraction,2020,116,R
# Poor Things,2023,141,R
# Encanto,2021,102,PG
# Uncharted,2022,116,PG-13
# Venom: Let There Be Carnage,2021,97,PG-13
# The Invisible Man,2020,124,R
# The Northman,2022,137,R
# The Banshees of Inisherin,2022,114,R
# Mission: Impossible - Dead Reckoning Part One,2023,163,PG-13
# All Quiet on the Western Front,2022,148,R
# Killers of the Flower Moon,2023,206,R
# Godzilla vs. Kong,2021,113,PG-13

# %%
#FIREFOX VERSION
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pdp
import re
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.service import Service
from selenium.webdriver.firefox.service import Service
# from selenium.webdriver import Chrome
from selenium.webdriver import Firefox
# from selenium.webdriver.chrome.options import Options
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime


# the first page to be accessed 
my_url = "http://www.imdb.com/search/title?sort=num_votes,desc&start=1&title_type=feature&year=2024,2024"

# IF YOU WANT TO DO HEADLESS BROWSER, use codes below
# options = Options()
# options.headless = True
# browser = webdriver.Firefox(options=options)


# THIS IS FOR NORMAL BROWSER SESSION (NOT HEADLESS
# define browser to get the first URL
browser = webdriver.Firefox() 

# define browser to get the second/detail URL
browser2 = webdriver.Firefox()

# check file availability and content is not empty
filename = "imdb_primary_data.csv"
filename2 = "imdb_secondary_data.csv"

def visualize_data():
    print("Visualize Something")
    

if os.path.isfile(filename) and os.path.getsize(filename) > 0:   
   
    os.remove(filename)
    os.remove(filename2)
    
#     print("The file exists and is not empty.")
    
#     visualize_data()
#     # Below you can do whatever you want to visualize the data
    
# else:
#     print("The file does not exist or is empty.")
    

    f = open(filename, "w")
    fheaders = "Name,Year,Durasi(Menit),Rating\n"
    f2 = open(filename2, "w")
    f2headers = "Name,Budget,Gross_US,Opening_Week,Open_Week_Date,Gross_World\n"
    
    f.write(fheaders)
    f2.write(f2headers)
    
    try:
        # open session for first URL
        browser.get(my_url)
        
        # We are going to have 2 different actions for "browser"
        # 1. Looking for primary data for each movie in the LIST
        # 2. Looking for LIST of movies based on the search and links to detail page
        #    and then run "browser2" to get the page using the link and extract 
        #    additional data for each movie in the LIST
        

        # ACTION 1
        first_page = BeautifulSoup(browser.page_source ,'html.parser')
        movies = first_page.find_all("div", {"class":"sc-b189961a-0 hBZnfJ"})
        
        count2 = 0
        print("Primary Data")
        print("-----------------------------------")
        for movie in movies:
            count2 += 1
            menit = 0
            rating = "Not Rated"
            name = re.sub(r"\d+. ","", movie.find("h3", {"class": "ipc-title__text"}).text)
            detil_line = movie.findAll("span", {"class": "sc-b189961a-8 kLaxqf dli-title-metadata-item"})
            if len(detil_line) > 2:        
                year_movie = detil_line[0].text
                durasi = detil_line[1].text
                durasi = durasi.split(" ")
                if len(durasi) > 1:
                    menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
                else:
                    menit = int(durasi[0].replace("h","")) * 60 
                # durasi_menit = 
                rating = detil_line[2].text
            elif len(detil_line) > 1:
                year_movie = detil_line[0].text
                durasi = detil_line[1].text
                durasi = durasi.split(" ")
                if len(durasi) > 1:
                    menit = int(durasi[0].replace("h","")) * 60 + int(durasi[1].replace("m",""))   
                else:
                    menit = int(durasi[0].replace("h","")) * 60 
            else:
                year_movie = detil_line[0].text        
        
            print("-----------------------------------")
            print(name + "," + year_movie + "," + str(menit) + "," + rating)  
            f.write(name + "," + year_movie + "," + str(menit) + "," + rating + "\n")
        
        # ACTION 2
        #
        # TECHNIQUE MENUNGGU SAMPAI SEMUA ELEMEN KE-LOAD
        # variasi 1
        # element_present = EC.presence_of_all_elements_located((By.CLASS_NAME, 'sc-b189961a-0 hBZnfJ'))
        # WebDriverWait(browser, 4).until(element_present)

        # variasi 2
        # element_preset = EC.presence_of_all_elements_located((By.XPATH, "//div[@class='sc-b189961a-0 hBZnfJ']"))
        # elems = WebDriverWait(browser,10).until(element_preset)

        # variasi 3
        # element_preset = EC.presence_of_all_elements_located((By.CSS_SELECTOR, "div[class='.sc-b189961a-0 hBZnfJ']"))
        # elems = WebDriverWait(browser,10).until(element_preset)

        ## TECHNIQUE TANPA MENUNGGU , ASUMSI KE-LOAD SEMUA
        # variasi 1
        # elems = browser.find_elements_by_xpath("//div@class='sc-eYdvao.kvdWiq'")
        # links = [elem.get_attribute('href') for elem in elems]

        # variasi 2    
        links = browser.find_elements(By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ"]')

        count = 0
        print("-----------------------------------")
        print("-----------------------------------")
        print("SECONDARY DATA")
        print("panjang ", len(links))
        movie_titles = browser.find_elements(By.XPATH, '//h3[@class="ipc-title__text"]')
        # print("panjang judul:", len(movie_titles)-1)
        
        # break
        
        for link in links:
            title = re.sub(r"\d+. ","", movie_titles[count].text)
            print("judul ke-" + str(count+1) + ": " + title)
            count += 1
            budget_num = 0
            gross_us_num = 0
            open_week_rev_num = 0
            open_week_date_std = "1900-01-01 00:00:00"
            gross_world_num = 0
            # # link = row.find_element(By.XPATH, '//a[@href="'+url+'"]')
            # # link = row.find_element(By.XPATH, '//a[@class="ipc-title-link-wrapper"]').get_attribute('href')
            # link = row.find_element(By.XPATH, '//div[@class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN dli-title"]/a').get_attribute('href')
            # # link = row.fine_element(By.CSS_SELECTOR, "a")
            print("----------------------")
            print(count, link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'), "\n")
            browser2.get(link.find_element(By.CSS_SELECTOR, "a").get_attribute('href'))

            # BOX OFFICE DATA ON THE 2ND URL
            det_page = browser2.page_source        
            container_rows = BeautifulSoup(det_page, "html.parser")        
            box_office_elements = container_rows.find("div",{"data-testid":"title-boxoffice-section"})
            if box_office_elements is not None:
                det_movie = box_office_elements.find_all("span",{"class":"ipc-metadata-list-item__list-content-item"})

                if len(det_movie) > 4:

                    budget = det_movie[0].text
                    gross_us = det_movie[1].text
                    open_week_rev = det_movie[2].text
                    open_week_date = det_movie[3].text            
                    gross_world = det_movie[4].text

                    print("budget = " + budget)
                    print("gross_us = " + gross_us)
                    print("opening_week_rev = " + open_week_rev)
                    print("opening_week_date = " + open_week_date)
                    print("gross_world = " + gross_world)

                    # print(det_page)
                    # print("\n")
                    print("=====================================")
                    budget_num = int(re.sub("[A-Z£€₹$,()a-z]","",budget))
                    gross_us_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_us))
                    open_week_rev_num = int(re.sub("[A-Z£€₹$,()a-z]","",open_week_rev))
                    open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
                    gross_world_num = int(re.sub("[A-Z£€₹$,()a-z]","",gross_world))

                    print("Data has been formatted to standard")
                    print("-----------------------------------")
                    print("budget =", budget_num)
                    print("gross_us =" , gross_us_num)
                    print("opening_week_rev =" , open_week_rev_num)
                    print("opening_week_date =", open_week_date_std)
                    print("gross_world =", gross_world_num)
            
            # UNTUK TEST SAJA
            # break
            
            f2.write(str(title) + "," + str(budget_num) + "," + str(gross_us_num) + "," + str(open_week_rev_num) + "," + str(open_week_date_std) + "," + str(gross_world_num) + "\n")

            # f2.write(budget_num + "," + gross_us_num + "," + open_week_rev_num + "," + open_week_date_std + "," + gross_world_num + "\n")

            
       
    except Exception as E:
        print(E)

f.close()
f2.close()
# Out:
# Primary Data
# -----------------------------------
# -----------------------------------
# Dune: Part Two,2024,166,PG-13
# -----------------------------------
# Road House,2024,121,R
# -----------------------------------
# The Beekeeper,2024,105,R
# -----------------------------------
# Damsel,2024,110,PG-13
# -----------------------------------
# Civil War,2024,109,R
# -----------------------------------
# Argylle,2024,139,PG-13
# -----------------------------------
# The Fall Guy,2024,126,PG-13
# -----------------------------------
# Madame Web,2024,116,PG-13
# -----------------------------------
# Godzilla x Kong: The New Empire,2024,115,PG-13
# -----------------------------------
# Challengers,2024,131,R
# -----------------------------------
# Murder Mubarak,2024,140,TV-MA
# -----------------------------------
# Teri Baaton Mein Aisa Uljha Jiya,2024,141,Not Rated
# -----------------------------------
# Monkey Man,2024,121,R
# -----------------------------------
# Fighter,2024,166,Not Rated
# -----------------------------------
# Ghostbusters: Frozen Empire,2024,115,PG-13
# -----------------------------------
# Shaitaan,2024,132,Not Rated
# -----------------------------------
# Rebel Moon - Part Two: The Scargiver,2024,122,PG-13
# -----------------------------------
# Ricky Stanicky,2024,113,R
# -----------------------------------
# Kung Fu Panda 4,2024,94,PG
# -----------------------------------
# Lift,2024,107,PG-13
# -----------------------------------
# Color of Victory,2024,157,Not Rated
# -----------------------------------
# Kingdom of the Planet of the Apes,2024,145,PG-13
# -----------------------------------
# The Idea of You,2024,115,R
# -----------------------------------
# Abigail,2024,109,R
# -----------------------------------
# Bade Miyan Chote Miyan,2024,163,Not Rated
# -----------------------------------
# Spaceman,2024,107,R
# -----------------------------------
# The Ministry of Ungentlemanly Warfare,2024,120,R
# -----------------------------------
# Madgaon Express,2024,143,Not Rated
# -----------------------------------
# Mean Girls,2024,112,PG-13
# -----------------------------------
# Furiosa: A Mad Max Saga,2024,148,R
# -----------------------------------
# Crew,2024,118,Not Rated
# -----------------------------------
# Merry Christmas,2024,144,Not Rated
# -----------------------------------
# Immaculate,2024,89,R
# -----------------------------------
# Hanu Man,2024,158,Not Rated
# -----------------------------------
# Bob Marley: One Love,2024,107,PG-13
# -----------------------------------
# Love Lies Bleeding,2024,104,R
# -----------------------------------
# Unfrosted,2024,97,PG-13
# -----------------------------------
# Land of Bad,2024,113,R
# -----------------------------------
# Upgraded,2024,104,R
# -----------------------------------
# Guntur Kaaram,2024,159,Not Rated
# -----------------------------------
# Article 370,2024,158,Not Rated
# -----------------------------------
# Night Swim,2024,98,PG-13
# -----------------------------------
# Lisa Frankenstein,2024,101,PG-13
# -----------------------------------
# Now or Never!,2024,0,Not Rated
# -----------------------------------
# Role Play,2024,100,R
# -----------------------------------
# Irish Wish,2024,93,TV-PG
# -----------------------------------
# Scoop,2024,102,TV-14
# -----------------------------------
# Manjummel Boys,2024,135,Not Rated
# -----------------------------------
# Maidaan,2024,181,Not Rated
# -----------------------------------
# The First Omen,2024,119,R
# -----------------------------------
# -----------------------------------
# SECONDARY DATA
# panjang  50
# judul ke-1: Dune: Part Two
# ----------------------
# 1 https://www.imdb.com/title/tt15239678/?ref_=sr_t_1
#
# budget = $190,000,000 (estimated)
# gross_us = $282,144,358
# opening_week_rev = $82,505,391
# opening_week_date = Mar 3, 2024
# gross_world = $711,844,358
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 190000000
# gross_us = 282144358
# opening_week_rev = 82505391
# opening_week_date = 2024-03-03 00:00:00
# gross_world = 711844358
# judul ke-2: Road House
# ----------------------
# 2 https://www.imdb.com/title/tt3359350/?ref_=sr_t_2
#
# judul ke-3: The Beekeeper
# ----------------------
# 3 https://www.imdb.com/title/tt15314262/?ref_=sr_t_3
#
# budget = $40,000,000 (estimated)
# gross_us = $66,220,535
# opening_week_rev = $16,576,007
# opening_week_date = Jan 14, 2024
# gross_world = $152,720,535
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 40000000
# gross_us = 66220535
# opening_week_rev = 16576007
# opening_week_date = 2024-01-14 00:00:00
# gross_world = 152720535
# judul ke-4: Damsel
# ----------------------
# 4 https://www.imdb.com/title/tt13452446/?ref_=sr_t_4
#
# judul ke-5: Civil War
# ----------------------
# 5 https://www.imdb.com/title/tt17279496/?ref_=sr_t_5
#
# budget = $50,000,000 (estimated)
# gross_us = $68,105,320
# opening_week_rev = $25,537,368
# opening_week_date = Apr 14, 2024
# gross_world = $113,212,647
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 50000000
# gross_us = 68105320
# opening_week_rev = 25537368
# opening_week_date = 2024-04-14 00:00:00
# gross_world = 113212647
# judul ke-6: Argylle
# ----------------------
# 6 https://www.imdb.com/title/tt15009428/?ref_=sr_t_6
#
# budget = $200,000,000 (estimated)
# gross_us = $45,207,275
# opening_week_rev = $17,473,540
# opening_week_date = Feb 4, 2024
# gross_world = $96,175,012
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 200000000
# gross_us = 45207275
# opening_week_rev = 17473540
# opening_week_date = 2024-02-04 00:00:00
# gross_world = 96175012
# judul ke-7: The Fall Guy
# ----------------------
# 7 https://www.imdb.com/title/tt1684562/?ref_=sr_t_7
#
# budget = $130,000,000 (estimated)
# gross_us = $73,891,385
# opening_week_rev = $27,747,035
# opening_week_date = May 5, 2024
# gross_world = $145,506,385
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 130000000
# gross_us = 73891385
# opening_week_rev = 27747035
# opening_week_date = 2024-05-05 00:00:00
# gross_world = 145506385
# judul ke-8: Madame Web
# ----------------------
# 8 https://www.imdb.com/title/tt11057302/?ref_=sr_t_8
#
# budget = $80,000,000 (estimated)
# gross_us = $43,817,106
# opening_week_rev = $15,335,860
# opening_week_date = Feb 18, 2024
# gross_world = $100,298,817
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 80000000
# gross_us = 43817106
# opening_week_rev = 15335860
# opening_week_date = 2024-02-18 00:00:00
# gross_world = 100298817
# judul ke-9: Godzilla x Kong: The New Empire
# ----------------------
# 9 https://www.imdb.com/title/tt14539740/?ref_=sr_t_9
#
# budget = $135,000,000 (estimated)
# gross_us = $195,501,633
# opening_week_rev = $80,006,561
# opening_week_date = Mar 31, 2024
# gross_world = $564,801,633
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 135000000
# gross_us = 195501633
# opening_week_rev = 80006561
# opening_week_date = 2024-03-31 00:00:00
# gross_world = 564801633
# judul ke-10: Challengers
# ----------------------
# 10 https://www.imdb.com/title/tt16426418/?ref_=sr_t_10
#
# budget = $55,000,000 (estimated)
# gross_us = $46,797,000
# opening_week_rev = $15,011,061
# opening_week_date = Apr 28, 2024
# gross_world = $81,897,000
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 55000000
# gross_us = 46797000
# opening_week_rev = 15011061
# opening_week_date = 2024-04-28 00:00:00
# gross_world = 81897000
# judul ke-11: Murder Mubarak
# ----------------------
# 11 https://www.imdb.com/title/tt27028399/?ref_=sr_t_11
#
# judul ke-12: Teri Baaton Mein Aisa Uljha Jiya
# ----------------------
# 12 https://www.imdb.com/title/tt27459160/?ref_=sr_t_12
#
# judul ke-13: Monkey Man
# ----------------------
# 13 https://www.imdb.com/title/tt9214772/?ref_=sr_t_13
#
# budget = $10,000,000 (estimated)
# gross_us = $25,116,955
# opening_week_rev = $10,119,435
# opening_week_date = Apr 7, 2024
# gross_world = $34,500,465
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 10000000
# gross_us = 25116955
# opening_week_rev = 10119435
# opening_week_date = 2024-04-07 00:00:00
# gross_world = 34500465
# judul ke-14: Fighter
# ----------------------
# 14 https://www.imdb.com/title/tt13818368/?ref_=sr_t_14
#
# budget = ₹250,000,000 (estimated)
# gross_us = $1,000,000
# opening_week_rev = $1,000,000
# opening_week_date = Jan 28, 2024
# gross_world = $3,800,771
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 250000000
# gross_us = 1000000
# opening_week_rev = 1000000
# opening_week_date = 2024-01-28 00:00:00
# gross_world = 3800771
# judul ke-15: Ghostbusters: Frozen Empire
# ----------------------
# 15 https://www.imdb.com/title/tt21235248/?ref_=sr_t_15
#
# budget = $100,000,000 (estimated)
# gross_us = $112,740,000
# opening_week_rev = $45,004,673
# opening_week_date = Mar 24, 2024
# gross_world = $200,279,314
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 100000000
# gross_us = 112740000
# opening_week_rev = 45004673
# opening_week_date = 2024-03-24 00:00:00
# gross_world = 200279314
# judul ke-16: Shaitaan
# ----------------------
# 16 https://www.imdb.com/title/tt27744786/?ref_=sr_t_16
#
# judul ke-17: Rebel Moon - Part Two: The Scargiver
# ----------------------
# 17 https://www.imdb.com/title/tt23137904/?ref_=sr_t_17
#
# judul ke-18: Ricky Stanicky
# ----------------------
# 18 https://www.imdb.com/title/tt1660648/?ref_=sr_t_18
#
# judul ke-19: Kung Fu Panda 4
# ----------------------
# 19 https://www.imdb.com/title/tt21692408/?ref_=sr_t_19
#
# budget = $85,000,000 (estimated)
# gross_us = $193,340,365
# opening_week_rev = $57,989,905
# opening_week_date = Mar 10, 2024
# gross_world = $539,305,365
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 85000000
# gross_us = 193340365
# opening_week_rev = 57989905
# opening_week_date = 2024-03-10 00:00:00
# gross_world = 539305365
# judul ke-20: Lift
# ----------------------
# 20 https://www.imdb.com/title/tt14371878/?ref_=sr_t_20
#
# judul ke-21: Color of Victory
# ----------------------
# 21 https://www.imdb.com/title/tt29808429/?ref_=sr_t_21
#
# judul ke-22: Kingdom of the Planet of the Apes
# ----------------------
# 22 https://www.imdb.com/title/tt11389872/?ref_=sr_t_22
#
# budget = $160,000,000 (estimated)
# gross_us = $126,549,252
# opening_week_rev = $58,400,788
# opening_week_date = May 12, 2024
# gross_world = $298,549,252
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 160000000
# gross_us = 126549252
# opening_week_rev = 58400788
# opening_week_date = 2024-05-12 00:00:00
# gross_world = 298549252
# judul ke-23: The Idea of You
# ----------------------
# 23 https://www.imdb.com/title/tt9466114/?ref_=sr_t_23
#
# judul ke-24: Abigail
# ----------------------
# 24 https://www.imdb.com/title/tt27489557/?ref_=sr_t_24
#
# budget = $28,000,000 (estimated)
# gross_us = $25,851,000
# opening_week_rev = $10,297,110
# opening_week_date = Apr 21, 2024
# gross_world = $40,915,000
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 28000000
# gross_us = 25851000
# opening_week_rev = 10297110
# opening_week_date = 2024-04-21 00:00:00
# gross_world = 40915000
# judul ke-25: Bade Miyan Chote Miyan
# ----------------------
# 25 https://www.imdb.com/title/tt18072316/?ref_=sr_t_25
#
# budget = ₹350,000,000 (estimated)
# gross_us = $689,505
# opening_week_rev = $493,782
# opening_week_date = Apr 14, 2024
# gross_world = $2,634,645
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 350000000
# gross_us = 689505
# opening_week_rev = 493782
# opening_week_date = 2024-04-14 00:00:00
# gross_world = 2634645
# judul ke-26: Spaceman
# ----------------------
# 26 https://www.imdb.com/title/tt11097384/?ref_=sr_t_26
#
# judul ke-27: The Ministry of Ungentlemanly Warfare
# ----------------------
# 27 https://www.imdb.com/title/tt5177120/?ref_=sr_t_27
#
# budget = $60,000,000 (estimated)
# gross_us = $20,504,850
# opening_week_rev = $8,913,698
# opening_week_date = Apr 21, 2024
# gross_world = $24,245,355
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 60000000
# gross_us = 20504850
# opening_week_rev = 8913698
# opening_week_date = 2024-04-21 00:00:00
# gross_world = 24245355
# judul ke-28: Madgaon Express
# ----------------------
# 28 https://www.imdb.com/title/tt26745657/?ref_=sr_t_28
#
# judul ke-29: Mean Girls
# ----------------------
# 29 https://www.imdb.com/title/tt11762114/?ref_=sr_t_29
#
# budget = $36,000,000 (estimated)
# gross_us = $72,404,248
# opening_week_rev = $28,635,307
# opening_week_date = Jan 14, 2024
# gross_world = $104,404,248
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 36000000
# gross_us = 72404248
# opening_week_rev = 28635307
# opening_week_date = 2024-01-14 00:00:00
# gross_world = 104404248
# judul ke-30: Furiosa: A Mad Max Saga
# ----------------------
# 30 https://www.imdb.com/title/tt12037194/?ref_=sr_t_30
#
# budget = $168,000,000 (estimated)
# gross_us = $25,500,000
# opening_week_rev = $25,500,000
# opening_week_date = May 26, 2024
# gross_world = $58,800,000
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 168000000
# gross_us = 25500000
# opening_week_rev = 25500000
# opening_week_date = 2024-05-26 00:00:00
# gross_world = 58800000
# judul ke-31: Crew
# ----------------------
# 31 https://www.imdb.com/title/tt21383812/?ref_=sr_t_31
#
# judul ke-32: Merry Christmas
# ----------------------
# 32 https://www.imdb.com/title/tt15392282/?ref_=sr_t_32
#
# judul ke-33: Immaculate
# ----------------------
# 33 https://www.imdb.com/title/tt23137390/?ref_=sr_t_33
#
# budget = $9,000,000 (estimated)
# gross_us = $15,671,307
# opening_week_rev = $5,338,921
# opening_week_date = Mar 24, 2024
# gross_world = $23,857,069
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 9000000
# gross_us = 15671307
# opening_week_rev = 5338921
# opening_week_date = 2024-03-24 00:00:00
# gross_world = 23857069
# judul ke-34: Hanu Man
# ----------------------
# 34 https://www.imdb.com/title/tt15433956/?ref_=sr_t_34
#
# judul ke-35: Bob Marley: One Love
# ----------------------
# 35 https://www.imdb.com/title/tt8521778/?ref_=sr_t_35
#
# judul ke-36: Love Lies Bleeding
# ----------------------
# 36 https://www.imdb.com/title/tt19637052/?ref_=sr_t_36
#
# judul ke-37: Unfrosted
# ----------------------
# 37 https://www.imdb.com/title/tt14914430/?ref_=sr_t_37
#
# judul ke-38: Land of Bad
# ----------------------
# 38 https://www.imdb.com/title/tt19864802/?ref_=sr_t_38
#
# budget = A$25,000,000 (estimated)
# gross_us = $4,620,045
# opening_week_rev = $1,840,510
# opening_week_date = Feb 18, 2024
# gross_world = $6,921,385
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 25000000
# gross_us = 4620045
# opening_week_rev = 1840510
# opening_week_date = 2024-02-18 00:00:00
# gross_world = 6921385
# judul ke-39: Upgraded
# ----------------------
# 39 https://www.imdb.com/title/tt21830902/?ref_=sr_t_39
#
# judul ke-40: Guntur Kaaram
# ----------------------
# 40 https://www.imdb.com/title/tt14564000/?ref_=sr_t_40
#
# judul ke-41: Article 370
# ----------------------
# 41 https://www.imdb.com/title/tt30970235/?ref_=sr_t_41
#
# judul ke-42: Night Swim
# ----------------------
# 42 https://www.imdb.com/title/tt9682428/?ref_=sr_t_42
#
# budget = $22,000,000 (estimated)
# gross_us = $32,494,740
# opening_week_rev = $11,797,155
# opening_week_date = Jan 7, 2024
# gross_world = $54,075,969
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 22000000
# gross_us = 32494740
# opening_week_rev = 11797155
# opening_week_date = 2024-01-07 00:00:00
# gross_world = 54075969
# judul ke-43: Lisa Frankenstein
# ----------------------
# 43 https://www.imdb.com/title/tt21188080/?ref_=sr_t_43
#
# budget = $13,000,000 (estimated)
# gross_us = $9,774,285
# opening_week_rev = $3,695,785
# opening_week_date = Feb 11, 2024
# gross_world = $9,927,714
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 13000000
# gross_us = 9774285
# opening_week_rev = 3695785
# opening_week_date = 2024-02-11 00:00:00
# gross_world = 9927714
# judul ke-44: Now or Never!
# ----------------------
# 44 https://www.imdb.com/title/tt19857862/?ref_=sr_t_44
#
# judul ke-45: Role Play
# ----------------------
# 45 https://www.imdb.com/title/tt12964320/?ref_=sr_t_45
#
# judul ke-46: Irish Wish
# ----------------------
# 46 https://www.imdb.com/title/tt21957774/?ref_=sr_t_46
#
# judul ke-47: Scoop
# ----------------------
# 47 https://www.imdb.com/title/tt21279806/?ref_=sr_t_47
#
# judul ke-48: Manjummel Boys
# ----------------------
# 48 https://www.imdb.com/title/tt26458038/?ref_=sr_t_48
#
# judul ke-49: Maidaan
# ----------------------
# 49 https://www.imdb.com/title/tt10869778/?ref_=sr_t_49
#
# judul ke-50: The First Omen
# ----------------------
# 50 https://www.imdb.com/title/tt5672290/?ref_=sr_t_50
#
# budget = $30,000,000 (estimated)
# gross_us = $20,104,637
# opening_week_rev = $8,353,710
# opening_week_date = Apr 7, 2024
# gross_world = $53,630,386
# =====================================
# Data has been formatted to standard
# -----------------------------------
# budget = 30000000
# gross_us = 20104637
# opening_week_rev = 8353710
# opening_week_date = 2024-04-07 00:00:00
# gross_world = 53630386

# %%
# THE FOLLOWING CODE IS TO MERGE 2 IMDB_DATA CSV FILES
# INTO ONE CSV BASED ON NAME
# NAME IS ADDED TO SECONDARY DATA MANUALLY

import pandas as pd
fn1 = 'imdb_primary_data.csv'
fn2 = 'imdb_secondary_data.csv'

fn3 = 'imdb_combined_data2.csv'

if os.path.isfile(fn3) and os.path.getsize(fn3) > 0:      
    os.remove(fn3)
    
# Read CSV files into dataframes
df1 = pd.read_csv(fn1)
df2 = pd.read_csv(fn2)

merged = df1.merge(df2,on='Name')
merged.to_csv("imdb_combined_data2.csv", index=False)

# %%
import streamlit as st
import pandas as pd
import numpy as np


# Read CSV files into dataframes
df = pd.read_csv('imdb_combined_data2.csv')
# df.astype("string")

df.keys()

df['Rating'] = df['Rating'].astype("string")
df['Rating']

df['Name'] = df['Name'].astype("string")
df['Name']

df['Year'] = pd.to_numeric(df['Year'])
df['Year']

df['Budget']
df_sorted = df.sort_values(by=['Budget'])
df_sel = df[['Rating','Gross_US', 'Gross_World']]
df_sel

# drop rows with all zeros techique 1
df_sel = df_sel.loc[df_sel['Gross_US'] * df_sel['Gross_World'] != 0]

# drop rows with all zeros techique 2

hsl = df_sel.loc[(df_sel[['Gross_US', 'Gross_World']] != 0).all(axis=1)]
hsl


df_sel2 = df[['Gross_US','Gross_World','Rating','Budget']]
df_sel2['Gross_US'] = df_sel2['Gross_US']/1000000
df_sel2['Gross_World'] = df_sel2['Gross_World']/1000000

chart_data2 = pd.DataFrame(df_sel2, columns=["Gross_US", "Gross_World", "Rating", "Budget"])
# st.scatter_chart
# df_sorted
# sorting
# label = df_sel.Rating.unique()
# label

hsl = hsl.groupby(['Rating']).sum()
hsl.index
# Out:
# C:\Users\HP ENVY\AppData\Local\Temp\ipykernel_26648\3955282335.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel2['Gross_US'] = df_sel2['Gross_US']/1000000
# C:\Users\HP ENVY\AppData\Local\Temp\ipykernel_26648\3955282335.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sel2['Gross_World'] = df_sel2['Gross_World']/1000000
# Index(['Not Rated', 'PG', 'PG-13', 'R'], dtype='string', name='Rating')
